# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import openweathermapy.core as owm
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
settings = {"units": "imperial", "appid": api_key}
i = 1
n = 1
s = ["name", "clouds.all", "sys.country", "dt", "main.humidity","coord.lat", "coord.lon","main.temp_max", "wind.speed"]
d = []
print ("Beginning Data Retrieval\n-----------------------------")
for city in cities:
    
    try:
        current_weather = owm.get_current(city, **settings)
        data = current_weather(*s)
        d.append(data)
        print(f"Processing Record {i} of Set {n} | {city}")
        i += 1
    except:
        print ("City not found. Skipping...")
   
    if i == 50:
        #time.sleep(5)
        n += 1
        i = 0      
print ("-----------------------------\nData Retrieval Complete\n -----------------------------")

data_dict = {"City": [i[0] for i in d]  , "Cloudiness": [i[1] for i in d], "Country": [i[2] for i in d], 
             "Date": [datetime.fromtimestamp(int(i[3])).strftime('%m/%d/%Y') for i in d], "Humidity": [i[4] for i in d],
             "Lat": [i[5] for i in d], "Lng": [i[6] for i in d],
             "Max Temp": [i[7] for i in d], "Wind Speed": [i[8] for i in d]}
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | riachao
# Processing Record 3 of Set 1 | yar-sale
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | seoul
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | fonte boa
# Processing Record 10 of Set 1 | araouane
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | ust-kuyga
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | kannur
# Processing Record 17 of Set 1 | lompoc
# Processing Record 18 of Set 1 | price
# Processing Record 19 of Set 1 | walvis bay
# Processing Record 20 of Set 1 | barmer
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | saint-georges
# City not found. Skipping...
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | alofi
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | provideniya
# City not found. Skipping...
# Processing Record 33 of Set 1 | nanakuli
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | esperance
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 38 of Set 1 | moose factory
# Processing Record 39 of Set 1 | richards bay
# Processing Record 40 of Set 1 | norman wells
# Processing Record 41 of Set 1 | tuatapere
# Processing Record 42 of Set 1 | eureka
# City not found. Skipping...
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | vila velha
# Processing Record 45 of Set 1 | makakilo city
# Processing Record 46 of Set 1 | chokurdakh
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 4 | luderitz
# Processing Record 40 of Set 4 | airai
# Processing Record 41 of Set 4 | boende
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 4 | yueyang
# Processing Record 43 of Set 4 | sao filipe
# Processing Record 44 of Set 4 | conceicao do araguaia
# Processing Record 45 of Set 4 | touros
# Processing Record 46 of Set 4 | brainerd
# City not found. Skipping...
# Processing Record 47 of Set 4 | the valley
# Processing Record 48 of Set 4 | rawson
# Processing Record 49 of Set 4 | soure
# Processing Record 0 of Set 5 | christchurch
# Processing Record 1 of Set 5 | pozo colorado
# Processing Record 2 of Set 5 | erdenet
# Processing Record 3 of Set 5 | mudon
# Processing Record 4 of Set 5 | lamu
# Processing Record 5 of Set 5 | dangriga
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 5 | agirish
# Processing Record 7 of Set 5 | ati
# Processing Record 8 of Set 5 | hobyo
# Processing Record 9 of Set 5 | miranda
# Processing Record 10 of Set 5 | flin flon
# Processing Record 11 of Set 5 | nome
# Processing Record 12 of Set 5 | kribi
# Processing Record 13 of Set 5 | xining
# Processing Record 14 of Set 5 | constitucion
# Processing Record 15 of Set 5 | orocue
# Processing Record 16 of Set 5 | talnakh
# Processing Record 17 of Set 5 | buluang
# City not found. Skipping...
# Processing Record 18 of Set 5 | boundiali
# Processing Record 19 of Set 5 | bikin
# Processing Record 20 of Set 5 | raudeberg
# Processing Record 21 of Set 5 | ayan
# Processing Record 22 of Set 5 | necochea
# Processing Record 23 of Set 5 | boca do acre
# City not found. Skipping...
# Processing Record 24 of Set 5 | port-cartier
# Processing Record 25 of Set 5 | kano
# Processing Record 26 of Set 5 | arman
# Processing Record 27 of Set 5 | pilani
# Processing Record 28 of Set 5 | mayo
# Processing Record 29 of Set 5 | abu dhabi
# Processing Record 30 of Set 5 | midland
# Processing Record 31 of Set 5 | pisco
# Processing Record 32 of Set 5 | lahar
# Processing Record 33 of Set 5 | chicama
# Processing Record 34 of Set 5 | shirakawa
# Processing Record 35 of Set 5 | berlevag
# Processing Record 36 of Set 5 | pierre
# Processing Record 37 of Set 5 | ilhabela
# Processing Record 38 of Set 5 | yeppoon
# Processing Record 39 of Set 5 | pacific grove
# Processing Record 40 of Set 5 | inhambane
# Processing Record 41 of Set 5 | jaisinghnagar
# Processing Record 42 of Set 5 | ulaangom
# Processing Record 43 of Set 5 | bolobo
# Processing Record 44 of Set 5 | aksarka
# City not found. Skipping...
# Processing Record 45 of Set 5 | petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 46 of Set 5 | bandarbeyla
# Processing Record 47 of Set 5 | metu
# Processing Record 48 of Set 5 | biltine
# Processing Record 49 of Set 5 | shimoda
# Processing Record 0 of Set 6 | sao joao da barra
# Processing Record 1 of Set 6 | superior
# Processing Record 2 of Set 6 | noumea
# Processing Record 3 of Set 6 | ancud
# City not found. Skipping...
# Processing Record 4 of Set 6 | qeshm
# Processing Record 5 of Set 6 | saint-augustin
# Processing Record 6 of Set 6 | mayaky
# Processing Record 7 of Set 6 | sept-iles
# Processing Record 8 of Set 6 | mackay
# Processing Record 9 of Set 6 | klaksvik
# Processing Record 10 of Set 6 | iqaluit
# Processing Record 11 of Set 6 | nova aurora
# Processing Record 12 of Set 6 | shenzhen
# Processing Record 13 of Set 6 | moscow
# Processing Record 14 of Set 6 | baruun-urt
# Processing Record 15 of Set 6 | brigantine
# Processing Record 16 of Set 6 | fort saint james
# Processing Record 17 of Set 6 | poum
# Processing Record 18 of Set 6 | haapiti
# City not found. Skipping...
# Processing Record 19 of Set 6 | at-bashi
# Processing Record 20 of Set 6 | san pedro
# Processing Record 21 of Set 6 | praia
# Processing Record 22 of Set 6 | haines junction
# Processing Record 23 of Set 6 | havelock
# Processing Record 24 of Set 6 | bahia blanca
# Processing Record 25 of Set 6 | beloha
# Processing Record 26 of Set 6 | albury
# Processing Record 27 of Set 6 | west wendover
# Processing Record 28 of Set 6 | mangit
# Processing Record 29 of Set 6 | dikson
# Processing Record 30 of Set 6 | bambous virieux
# Processing Record 31 of Set 6 | ilulissat
# Processing Record 32 of Set 6 | urucuca
# Processing Record 33 of Set 6 | palauig
# Processing Record 34 of Set 6 | port macquarie
# Processing Record 35 of Set 6 | fort nelson
# Processing Record 36 of Set 6 | astoria
# Processing Record 37 of Set 6 | zhengjiatun
# City not found. Skipping...
# Processing Record 38 of Set 6 | goderich
# Processing Record 39 of Set 6 | luquillo
# City not found. Skipping...
# Processing Record 40 of Set 6 | margate
# Processing Record 41 of Set 6 | andros town
# Processing Record 42 of Set 6 | hearst
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | fairmont
# Processing Record 45 of Set 6 | rexburg
# Processing Record 46 of Set 6 | tautira
# Processing Record 47 of Set 6 | mmabatho
# Processing Record 48 of Set 6 | san borja
# City not found. Skipping...
# Processing Record 49 of Set 6 | impfondo
# Processing Record 0 of Set 7 | nuevitas
# Processing Record 1 of Set 7 | palatka
# Processing Record 2 of Set 7 | mahebourg
# Processing Record 3 of Set 7 | mlonggo
# Processing Record 4 of Set 7 | george
# Processing Record 5 of Set 7 | takoradi
# Processing Record 6 of Set 7 | salinas
# Processing Record 7 of Set 7 | beterou
# City not found. Skipping...
# Processing Record 8 of Set 7 | tateyama
# Processing Record 9 of Set 7 | fenoarivo
# Processing Record 10 of Set 7 | bouna
# Processing Record 11 of Set 7 | port blair
# Processing Record 12 of Set 7 | nanchang
# City not found. Skipping...
# Processing Record 13 of Set 7 | mount gambier
# Processing Record 14 of Set 7 | grand-lahou
# Processing Record 15 of Set 7 | buin
# City not found. Skipping...
# Processing Record 16 of Set 7 | batagay
# Processing Record 17 of Set 7 | pangai
# Processing Record 18 of Set 7 | bontang
# Processing Record 19 of Set 7 | hovd
# Processing Record 20 of Set 7 | huangzhou
# Processing Record 21 of Set 7 | kaeo
# Processing Record 22 of Set 7 | voznesenye
# Processing Record 23 of Set 7 | marienburg
# Processing Record 24 of Set 7 | cabedelo
# Processing Record 25 of Set 7 | pitimbu
# Processing Record 46 of Set 8 | old shinyanga
# Processing Record 47 of Set 8 | keti bandar
# Processing Record 48 of Set 8 | batagay-alyta
# Processing Record 49 of Set 8 | belmonte
# Processing Record 0 of Set 9 | leningradskiy
# Processing Record 1 of Set 9 | novyy urengoy
# City not found. Skipping...
# Processing Record 2 of Set 9 | mount isa
# Processing Record 3 of Set 9 | sao felix do xingu
# City not found. Skipping...
# Processing Record 4 of Set 9 | beyneu
# Processing Record 5 of Set 9 | beisfjord
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 9 | toora-khem
# Processing Record 7 of Set 9 | buraydah
# Processing Record 8 of Set 9 | orange
# Processing Record 9 of Set 9 | clyde river
# Processing Record 10 of Set 9 | lasa
# City not found. Skipping...
# Processing Record 11 of Set 9 | natal
# Processing Record 12 of Set 9 | suraabad
# Processing Record 13 of Set 9 | karratha
# Processing Record 14 of Set 9 | general roca
# Processing Record 15 of Set 9 | hami
# Processing Record 16 of Set 9 | emerald
# Processing Record 17 of Set 9 | vila franca do campo
# Processing Record 18 of Set 9 | upernavik
# Processing Record 19 of Set 9 | asosa
# Processing Record 20 of Set 9 | dobryanka
# Processing Record 21 of Set 9 | mantua
# Processing Record 22 of Set 9 | beringovskiy
# Processing Record 23 of Set 9 | izumo
# Processing Record 24 of Set 9 | danielskuil
# Processing Record 25 of Set 9 | sao caetano de odivelas
# Processing Record 26 of Set 9 | kyzyl-suu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 9 | semey
# City not found. Skipping...
# Processing Record 28 of Set 9 | saint george
# Processing Record 29 of Set 9 | sindor
# Processing Record 30 of Set 9 | lodwar
# Processing Record 31 of Set 9 | mana
# City not found. Skipping...
# Processing Record 32 of Set 9 | bela
# Processing Record 33 of Set 9 | jieshi
# Processing Record 34 of Set 9 | yerbogachen
# Processing Record 35 of Set 9 | kuryk
# Processing Record 36 of Set 9 | west bay
# Processing Record 37 of Set 9 | tonantins
# Processing Record 38 of Set 9 | inuvik
# Processing Record 39 of Set 9 | samarai
# Processing Record 40 of Set 9 | carlos chagas
# Processing Record 41 of Set 9 | baykalsk
# Processing Record 42 of Set 9 | say
# Processing Record 43 of Set 9 | tromso
# Processing Record 44 of Set 9 | riacho de santana
# Processing Record 45 of Set 9 | tonota
# Processing Record 46 of Set 9 | ryazanovskiy
# Processing Record 47 of Set 9 | dawlatabad
# Processing Record 48 of Set 9 | auki
# Processing Record 49 of Set 9 | igarka
# Processing Record 0 of Set 10 | tuensang
# Processing Record 1 of Set 10 | camopi
# Processing Record 2 of Set 10 | ugoofaaru
# Processing Record 3 of Set 10 | waddan
# Processing Record 4 of Set 10 | dinguiraye
# Processing Record 5 of Set 10 | praia da vitoria
# City not found. Skipping...
# Processing Record 6 of Set 10 | fairbanks
# Processing Record 7 of Set 10 | yumen
# Processing Record 8 of Set 10 | susanville
# Processing Record 9 of Set 10 | zhigansk
# Processing Record 10 of Set 10 | plopu
# Processing Record 11 of Set 10 | dryden
# Processing Record 12 of Set 10 | coquimbo
# Processing Record 13 of Set 10 | namatanai
# Processing Record 14 of Set 10 | tulsipur
# Processing Record 15 of Set 10 | opuwo
# Processing Record 16 of Set 10 | tapes
# Processing Record 17 of Set 10 | imbituba
# Processing Record 18 of Set 10 | bilibino
# Processing Record 19 of Set 10 | okha
# Processing Record 20 of Set 10 | chenzhou
# Processing Record 21 of Set 10 | bahia honda
# Processing Record 22 of Set 10 | ober-ramstadt
# Processing Record 23 of Set 10 | kamina
# Processing Record 24 of Set 10 | la tuque
# Processing Record 25 of Set 10 | ghanzi
# Processing Record 26 of Set 10 | port lincoln
# Processing Record 27 of Set 10 | labuan
# City not found. Skipping...
# Processing Record 28 of Set 10 | vestmannaeyjar
# Processing Record 29 of Set 10 | mahon
# Processing Record 30 of Set 10 | valentin gomez farias
# Processing Record 31 of Set 10 | vila
# Processing Record 32 of Set 10 | charters towers
# Processing Record 33 of Set 10 | kingaroy
# Processing Record 34 of Set 10 | dingle
# Processing Record 35 of Set 10 | baytown
# Processing Record 36 of Set 10 | rosarito
# Processing Record 37 of Set 10 | ossora
# Processing Record 38 of Set 10 | fort morgan
# Processing Record 39 of Set 10 | smithers
# Processing Record 40 of Set 10 | kununurra
# Processing Record 41 of Set 10 | trairi
# Processing Record 42 of Set 10 | rio grande
# Processing Record 43 of Set 10 | ojojona
# Processing Record 44 of Set 10 | lukovetskiy
# Processing Record 45 of Set 10 | labuhan
# Processing Record 46 of Set 10 | tezu
# Processing Record 47 of Set 10 | biak
# City not found. Skipping...
# Processing Record 48 of Set 10 | college
# City not found. Skipping...
# Processing Record 49 of Set 10 | vytegra
# Processing Record 0 of Set 11 | sinnamary
# Processing Record 1 of Set 11 | vancouver
# Processing Record 2 of Set 11 | santiago del estero
# Processing Record 3 of Set 11 | muros
# Processing Record 4 of Set 11 | nauta
# Processing Record 5 of Set 11 | katobu
# Processing Record 6 of Set 11 | elizabeth city
# Processing Record 7 of Set 11 | oskaloosa
# Processing Record 8 of Set 11 | mwense
# Processing Record 9 of Set 11 | lesosibirsk
# Processing Record 10 of Set 11 | lahij
# City not found. Skipping...
# Processing Record 11 of Set 11 | saint-francois
# Processing Record 12 of Set 11 | moyale
# City not found. Skipping...
# Processing Record 13 of Set 11 | mehran
# Processing Record 14 of Set 11 | de aar
# Processing Record 15 of Set 11 | arlit
# Processing Record 16 of Set 11 | nelson bay
# Processing Record 17 of Set 11 | broome
# Processing Record 18 of Set 11 | soe
# Processing Record 19 of Set 11 | anadyr
# City not found. Skipping...
# Processing Record 20 of Set 11 | sorland
# Processing Record 21 of Set 11 | ayorou
# Processing Record 22 of Set 11 | awjilah
# Processing Record 23 of Set 11 | isoka
# Processing Record 24 of Set 11 | mao
# Processing Record 25 of Set 11 | kenora
# Processing Record 26 of Set 11 | khorixas
# Processing Record 27 of Set 11 | coihaique
# Processing Record 28 of Set 11 | gat
# Processing Record 29 of Set 11 | nouadhibou
# Processing Record 30 of Set 11 | port keats
# Processing Record 31 of Set 11 | kamogawa
# Processing Record 32 of Set 11 | bursa
# Processing Record 33 of Set 11 | viseu
# Processing Record 34 of Set 11 | kaihua
# Processing Record 35 of Set 11 | gladstone
# Processing Record 36 of Set 11 | fare
# Processing Record 37 of Set 11 | hachinohe
# Processing Record 38 of Set 11 | oudtshoorn
# Processing Record 39 of Set 11 | guerrero negro
# Processing Record 40 of Set 11 | bondo
# Processing Record 41 of Set 11 | denpasar
# Processing Record 42 of Set 11 | talas
# Processing Record 43 of Set 11 | abengourou
# Processing Record 44 of Set 11 | kavieng
# Processing Record 45 of Set 11 | sur
# Processing Record 46 of Set 11 | jauharabad
# Processing Record 47 of Set 11 | sydney
# -----------------------------
# Data Retrieval Complete
#  -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df =  pd.DataFrame(data_dict)
weather_df.count()
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
weather_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Severo-Kurilsk         100      RU  10/04/2019        81  50.68  156.12
# 1         Riachao          91      BR  10/04/2019        53  -7.36  -46.62
# 2        Yar-Sale          17      RU  10/04/2019        80  66.83   70.83
# 3    Punta Arenas          20      CL  10/04/2019        45 -53.16  -70.91
# 4      Georgetown          40      GY  10/04/2019        74   6.80  -58.16
#
#    Max Temp  Wind Speed
# 0     39.29       11.52
# 1     82.64        1.39
# 2     32.42       11.99
# 3     42.80       23.04
# 4     84.20        9.17

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Plotting Max Temperature vs Latitude
lat_temp_df = weather_df[["Lat", "Max Temp"]]
Date = weather_df["Date"].unique()[0]
multi_plot = lat_temp_df.plot.scatter(x = "Lat", y= "Max Temp", figsize=(7,4))
plt.title(f"City Latitude vs. Max Temperature ({Date})")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temperature (F)", fontsize = 12)
plt.grid()
plt.savefig('Latitude_Temperature.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Plotting Humidity vs Latitude
lat_temp_df = weather_df[["Lat", "Humidity"]]
Date = weather_df["Date"].unique()[0].replace("-","/")
multi_plot = lat_temp_df.plot.scatter(x = "Lat", y= "Humidity", figsize=(7,4))
plt.title(f"City Latitude vs. Humidity ({Date})")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)
plt.grid()
plt.savefig('Latitude_Humidity.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Plotting Cloudiness vs Latitude
lat_temp_df = weather_df[["Lat", "Cloudiness"]]
Date = weather_df["Date"].unique()[0].replace("-","/")
multi_plot = lat_temp_df.plot.scatter(x = "Lat", y= "Cloudiness", figsize=(7,4))

plt.title(f"City Latitude vs. Cloudiness ({Date})")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)
plt.grid()
plt.savefig('Latitude_Cloudiness.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Plotting Wind Speed vs Latitude
lat_temp_df = weather_df[["Lat", "Wind Speed"]]
Date = weather_df["Date"].unique()[0].replace("-","/")
multi_plot = lat_temp_df.plot.scatter(x = "Lat", y= "Wind Speed", figsize=(7,4))

plt.title(f"City Latitude vs. Wind Speed ({Date})")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed (mph)", fontsize = 12)
plt.grid()
plt.savefig('Latitude_WindSpeed.png')
plt.show()
